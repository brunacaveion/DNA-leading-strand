# %%
import pandas as pd
import numpy as np
import gzip

# %% [markdown]
# # Import sets

# %%
path = "C:/Users/Bruna/OneDrive/Documentos/estudos sobre DNA/"
file = "fullBacteriaP1.txt"
txt1 = pd.read_csv(path+file, sep=',', header=None)
txt1
# Out:
#                                                       0
# 0     0.3211370672670980 0.1298366236446730 0.284628...
# 1     0.3191806615776080 0.1953689567430030 0.267221...
# 2     0.3848945828642780 0.1566695557171650 0.163762...
# 3     0.4206054630864700 0.1566239440159290 0.179222...
# 4     0.3476212679068120 0.1868820039551750 0.204680...
# ...                                                 ...
# 9217  0.2082055436606680 0.2951218100804350 0.252994...
# 9218  0.1873094834170310 0.3050901299737080 0.279277...
# 9219  0.1824403786462050 0.3087933062137310 0.269243...
# 9220  0.1784117779043480 0.3186843059079380 0.257102...
# 9221  0.1932692984307930 0.3064844134825140 0.266413...
#
# [9222 rows x 1 columns]

# %%
path = "C:/Users/Bruna/OneDrive/Documentos/estudos sobre DNA/"
file = "fullBacteriaP2.txt"
txt2 = pd.read_csv(path+file, sep=',', header=None)
txt2
# Out:
#                                                       0
# 0     0.3582422187511900 0.1824005993879130 0.203804...
# 1     0.3202263750515830 0.2014711758271270 0.252032...
# 2     0.3902239469763220 0.1697560865763170 0.146903...
# 3     0.4225163516506150 0.1462738837101510 0.156172...
# 4     0.3444835136001510 0.1891483460380290 0.202895...
# ...                                                 ...
# 9217  0.2176767327758970 0.2771059360099510 0.258102...
# 9218  0.1776783938299250 0.3253148881288940 0.271782...
# 9219  0.1844965213904520 0.3219915091336750 0.257123...
# 9220  0.1807911854506840 0.3389530510199570 0.239284...
# 9221  0.1824504433778790 0.3328849001730690 0.256802...
#
# [9222 rows x 1 columns]

# %% [markdown]
# # organize sets to become dataframes with entries type float64

# %%
txt1 = txt1.rename(columns={0:"column"})

# %%
txt2 = txt2.rename(columns={0:"column2"})
txt2
# Out:
#                                                 column2
# 0     0.3582422187511900 0.1824005993879130 0.203804...
# 1     0.3202263750515830 0.2014711758271270 0.252032...
# 2     0.3902239469763220 0.1697560865763170 0.146903...
# 3     0.4225163516506150 0.1462738837101510 0.156172...
# 4     0.3444835136001510 0.1891483460380290 0.202895...
# ...                                                 ...
# 9217  0.2176767327758970 0.2771059360099510 0.258102...
# 9218  0.1776783938299250 0.3253148881288940 0.271782...
# 9219  0.1844965213904520 0.3219915091336750 0.257123...
# 9220  0.1807911854506840 0.3389530510199570 0.239284...
# 9221  0.1824504433778790 0.3328849001730690 0.256802...
#
# [9222 rows x 1 columns]

# %%
df1=txt1.column.str.split(pat=' ',expand=True)

# %%
df2=txt2.column2.str.split(pat=' ',expand=True)
df2
# Out:
#                       0                   1                   2   \
# 0     0.3582422187511900  0.1824005993879130  0.2038045893811830
# 1     0.3202263750515830  0.2014711758271270  0.2520322008030550
# 2     0.3902239469763220  0.1697560865763170  0.1469035117678190
# 3     0.4225163516506150  0.1462738837101510  0.1561724262244420
# 4     0.3444835136001510  0.1891483460380290  0.2028951605816560
# ...                  ...                 ...                 ...
# 9217  0.2176767327758970  0.2771059360099510  0.2581024117199920
# 9218  0.1776783938299250  0.3253148881288940  0.2717823021001100
# 9219  0.1844965213904520  0.3219915091336750  0.2571236053524700
# 9220  0.1807911854506840  0.3389530510199570  0.2392849241116860
# 9221  0.1824504433778790  0.3328849001730690  0.2568023266187310
#
#                       3                   4                   5   \
# 0     0.2555525924797140  0.2803223871768120  0.2264515227946790
# ...

# %%
df1 = df1.astype(float)
df2 = df2.astype(float)

# %%
df1.to_csv('P1_inicial_organizada.csv')

# %%
df2.to_csv('P2_inicial_organizada.csv')

# %% [markdown]
# # Find pi value for the 1st line

# %%
# get 1st line and organize as a 4x4 matrix considering the order we need, which is every 4 elements is a line of the matrix
line1=df1.iloc[:1]
a1 = np.array([[line1[0], line1[1], line1[2], line1[3]],
             [line1[4], line1[5], line1[6], line1[7]],
             [line1[8], line1[9], line1[10], line1[11]],
             [line1[12], line1[13], line1[14], line1[15]]])
matrix1=np.array(a1).reshape(4,4)
matrix1
# Out:
# array([[0.32113707, 0.12983662, 0.28462868, 0.26439763],
#        [0.28672405, 0.1834572 , 0.18888948, 0.34092926],
#        [0.33460657, 0.20582896, 0.22956045, 0.23000403],
#        [0.21963137, 0.20771228, 0.21894823, 0.35370813]])

# %%
# transpose the matrix because we need eigenvector from the left
transposta1 = np.transpose(matrix1)
transposta1
# Out:
# array([[0.32113707, 0.28672405, 0.33460657, 0.21963137],
#        [0.12983662, 0.1834572 , 0.20582896, 0.20771228],
#        [0.28462868, 0.18888948, 0.22956045, 0.21894823],
#        [0.26439763, 0.34092926, 0.23000403, 0.35370813]])

# %%
b1,r1 = np.linalg.eig(transposta1)
b1
# Out:
# array([ 1.        +0.j        ,  0.14030623+0.j        ,
#        -0.0262217 +0.05142939j, -0.0262217 -0.05142939j])

# %%
r1
# Out:
# array([[-0.56622126+0.j        , -0.58660633+0.j        ,
#         -0.02011774+0.41514231j, -0.02011774-0.41514231j],
#        [-0.35482565+0.j        ,  0.28174796+0.j        ,
#         -0.61140075+0.j        , -0.61140075-0.j        ],
#        [-0.46191449+0.j        , -0.36237262+0.j        ,
#          0.19342944-0.47018564j,  0.19342944+0.47018564j],
#        [-0.58320429+0.j        ,  0.66723098+0.j        ,
#          0.43808905+0.05504333j,  0.43808905-0.05504333j]])

# %%
b1[0]
# Out:
# (0.9999999999999999+0j)

# %%
r1[:,0]
# Out:
# array([-0.56622126+0.j, -0.35482565+0.j, -0.46191449+0.j, -0.58320429+0.j])

# %%
norms = np.linalg.norm(r1[:,0])

# %%
normal=r1[:,0]/(r1[0,0]+r1[1,0]+r1[2,0]+r1[3,0])
normal
# Out:
# array([0.28798248-0.j, 0.18046579-0.j, 0.23493162-0.j, 0.29662011-0.j])

# %% [markdown]
# # Generalize the method for the rest of the data

# %%
# organizing all lines as the matrix needed and store in one table
lenghtdf1 = list(range(1,9222))
lista=[matrix1]
for i in lenghtdf1:
    line=df1.iloc[i:i+1]
    a = np.array([[line[0], line[1], line[2], line[3]],
             [line[4], line[5], line[6], line[7]],
             [line[8], line[9], line[10], line[11]],
             [line[12], line[13], line[14], line[15]]])
    matrix=np.array(a).reshape(4,4)
    lista.append(matrix)

# %%
transpostadf1=[]
for n in lista:
    transposta = np.transpose(n)
    transpostadf1.append(transposta)

# %%
transpostadf1
# Out:
# [array([[0.32113707, 0.28672405, 0.33460657, 0.21963137],
#         [0.12983662, 0.1834572 , 0.20582896, 0.20771228],
#         [0.28462868, 0.18888948, 0.22956045, 0.21894823],
#         [0.26439763, 0.34092926, 0.23000403, 0.35370813]]),
#  array([[0.31918066, 0.25793418, 0.37782468, 0.1339357 ],
#         [0.19536896, 0.22053332, 0.15256508, 0.31342897],
#         [0.26722137, 0.22815213, 0.24399606, 0.2392592 ],
#         [0.21822901, 0.29338038, 0.22561418, 0.31337613]]),
#  array([[0.38489458, 0.34335664, 0.27096272, 0.23192345],
#         [0.15666956, 0.18962698, 0.2667116 , 0.16163373],
#         [0.16376267, 0.21322198, 0.19631396, 0.22028263],
#         [0.29467319, 0.25379441, 0.26601172, 0.38616018]]),
#  array([[0.42060546, 0.39289327, 0.3264885 , 0.26551596],
#         [0.15662394, 0.19606999, 0.17954411, 0.1271986 ],
#         [0.17922249, 0.06387879, 0.18974258, 0.20886324],
#         [0.24354811, 0.34715795, 0.3042248 , 0.3984222 ]]),
# ...

# %%
eingenvaluedf1 = []
eingenvectordf1 = []
for matriz in transpostadf1:
    b,r = np.linalg.eig(matriz)
    eingenvaluedf1.append(b)
    eingenvectordf1.append(r)

# %%
# it looks like the eingenvalue 1 is always the first element in the matrix. We need to validate that
eingenvaluedf1
# Out:
# [array([ 1.        +0.j        ,  0.14030623+0.j        ,
#         -0.0262217 +0.05142939j, -0.0262217 -0.05142939j]),
#  array([ 1.        ,  0.16435974, -0.00513232, -0.06214124]),
#  array([ 1.        +0.j        ,  0.10176435+0.05060723j,
#          0.10176435-0.05060723j, -0.046533  +0.j        ]),
#  array([1.        +0.j        , 0.1569511 +0.j        ,
#         0.02394457+0.06291099j, 0.02394457-0.06291099j]),
#  array([1.        +0.j        , 0.12002159+0.06664155j,
#         0.12002159-0.06664155j, 0.09908537+0.j        ]),
#  array([1.        +0.j        , 0.17819104+0.j        ,
#         0.02959495+0.03834368j, 0.02959495-0.03834368j]),
#  array([ 1.        +0.j        ,  0.06862966+0.06241399j,
#          0.06862966-0.06241399j, -0.08693732+0.j        ]),
#  array([ 1.        +0.j        ,  0.03744965+0.08714167j,
#          0.03744965-0.08714167j, -0.10910603+0.j        ]),
#  array([1.        +0.j        , 0.17167797+0.j        ,
# ...

# %%
# how to access the first element of the second matrix in eingenvaluedf1
primeiro = eingenvaluedf1[1]
primeiro[0].round()
# Out:
# 1.0

# %%
# getting all the first elements of all matrices and putting them on a table
eingenvalues1 = []
for i in lenghtdf1:
    primeiro = eingenvaluedf1[i]
    valor = primeiro[0].round()
    eingenvalues1.append(valor)

# %%
eingenvalues1
# Out:
# [1.0,
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  1.0,
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  1.0,
#  1.0,
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  1.0,
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  1.0,
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  1.0,
#  (1+0j),
#  (1+0j),
#  1.0,
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
#  (1+0j),
# ...

# %%
# this code shows us all the eingenvalues are 1 for the first element of all the matrices, so we can consider the first 
# eingenvalue as the pi we are looking for
for n in eingenvalues1:
    if n != 1:
        print(n)

# %%
# table with all the pi functions we where looking for
pidf1 = []
for matriz in eingenvectordf1:
    vetor = matriz[:,0]/(matriz[0,0]+matriz[1,0]+matriz[2,0]+matriz[3,0])
    pidf1.append(vetor)

# %%
pidf1
# Out:
# [array([0.28798248-0.j, 0.18046579-0.j, 0.23493162-0.j, 0.29662011-0.j]),
#  array([0.27157408, 0.22130704, 0.2455581 , 0.26156078]),
#  array([0.30735233-0.j, 0.1860024 -0.j, 0.19687887-0.j, 0.30976639-0.j]),
#  array([0.35041689+0.j, 0.15737058+0.j, 0.17236461+0.j, 0.31984792+0.j]),
#  array([0.26438985-0.j, 0.2379263 -0.j, 0.24026164-0.j, 0.25742222-0.j]),
#  array([0.31429439+0.j, 0.19735379+0.j, 0.20450097+0.j, 0.28385086+0.j]),
#  array([0.24428127-0.j, 0.24699198-0.j, 0.26317678-0.j, 0.24554998-0.j]),
#  array([0.2084121 -0.j, 0.29226258-0.j, 0.29211173-0.j, 0.20721359-0.j]),
#  array([0.30715234+0.j, 0.18558512+0.j, 0.20116179+0.j, 0.30610074+0.j]),
#  array([0.29451787+0.j, 0.21457854+0.j, 0.22157966+0.j, 0.26932393+0.j]),
#  array([0.30562885, 0.18621488, 0.20436871, 0.30378757]),
#  array([0.29070124-0.j, 0.18474351-0.j, 0.22290076-0.j, 0.30165448-0.j]),
#  array([0.40948398-0.j, 0.10873352-0.j, 0.17648147-0.j, 0.30530104-0.j]),
# ...

# %% [markdown]
# # is the least DNA a leading strand?

# %%
# In order to know if is a leading strand, we need to verify if piG + piT > piA + piC, 
# where pi = [piA piC piG piT] was the eingenvectors found previously

# %%
test = pidf1[9221]
GTtest = test[2]+test[3]
ACtest = test[0]+test[1]

if GTtest > ACtest:
    print('It is leading strand!')
else:
    print('It is not leading strand')
# Note that GTtest > ACtest, that means the DNA strand on the position 1 of df1 is the leading strand
# Out:
# It is leading strand!

# %%
GTtest
# Out:
# (0.5117665145336614-0j)

# %%
ACtest
# Out:
# (0.4882334854663387-0j)

# %% [markdown]
# # Generalize for all lines and get only the leading strand lines

# %%
lenghtdf1 = list(range(1,9222))
classificacaodf1=[]
for i in lenghtdf1:
    matrix = pidf1[i]
    GT = matrix[2]+matrix[3]
    AC = matrix[0]+matrix[1]
    if GT>AC:
        classificacaodf1.append('leading')
    else:
        classificacaodf1.append('no')

# %%
classificador = pd.DataFrame(classificacaodf1)

# %%
df1['is it leading'] = classificador

# %%
df1
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.321137  0.129837  0.284629  0.264398  0.286724  0.183457  0.188889
# 1     0.319181  0.195369  0.267221  0.218229  0.257934  0.220533  0.228152
# 2     0.384895  0.156670  0.163763  0.294673  0.343357  0.189627  0.213222
# 3     0.420605  0.156624  0.179222  0.243548  0.392893  0.196070  0.063879
# 4     0.347621  0.186882  0.204680  0.260816  0.276402  0.326196  0.179280
# ...        ...       ...       ...       ...       ...       ...       ...
# 9217  0.208206  0.295122  0.252995  0.243678  0.194308  0.221671  0.436505
# 9218  0.187309  0.305090  0.279278  0.228323  0.151252  0.198895  0.515309
# 9219  0.182440  0.308793  0.269244  0.239523  0.155995  0.203883  0.510171
# 9220  0.178412  0.318684  0.257102  0.245802  0.153285  0.199025  0.526943
# 9221  0.193269  0.306484  0.266413  0.233833  0.151770  0.198705  0.520735
#
# ...

# %%
# The least column wasn't classified for some reason
pd.isnull(df1['is it leading']).values.sum()
#was we calculated previously the least line is strand, I'll add thid to the least line
# Out:
# 1

# %%
df1 = df1.replace(to_replace = np.nan, value ='leading')

# %%
# No NaN values anymore!
pd.isnull(df1['is it leading']).values.sum()
# Out:
# 0

# %% [markdown]
# # The same classification for df2

# %%
# get 1st line and organize as a 4x4 matrix considering the order we need, which is every 4 elements is a line of the matrix
line1=df2.iloc[:1]
a1 = np.array([[line1[0], line1[1], line1[2], line1[3]],
             [line1[4], line1[5], line1[6], line1[7]],
             [line1[8], line1[9], line1[10], line1[11]],
             [line1[12], line1[13], line1[14], line1[15]]])
matrix1=np.array(a1).reshape(4,4)
matrix1
# Out:
# array([[0.35824222, 0.1824006 , 0.20380459, 0.25555259],
#        [0.28032239, 0.22645152, 0.14428551, 0.34894058],
#        [0.34142592, 0.26587022, 0.18404757, 0.20865629],
#        [0.23090077, 0.26755756, 0.1767343 , 0.32480737]])

# %%
# organizing all lines as the matrix needed and store in one table
lenghtdf1 = list(range(1,9222))
lista=[matrix1]
for i in lenghtdf1:
    line=df2.iloc[i:i+1]
    a = np.array([[line[0], line[1], line[2], line[3]],
             [line[4], line[5], line[6], line[7]],
             [line[8], line[9], line[10], line[11]],
             [line[12], line[13], line[14], line[15]]])
    matrix=np.array(a).reshape(4,4)
    lista.append(matrix)

# %%
transpostadf1=[]
for n in lista:
    transposta = np.transpose(n)
    transpostadf1.append(transposta)

# %%
eingenvaluedf1 = []
eingenvectordf1 = []
for matriz in transpostadf1:
    b,r = np.linalg.eig(matriz)
    eingenvaluedf1.append(b)
    eingenvectordf1.append(r)

# %%
# this code shows us all the eingenvalues are 1 for the first element of all the matrices, so we can consider the first 
# eingenvalue as the pi we are looking for
for n in eingenvalues1:
    if n != 1:
        print(n)

# %%
# getting all the first elements of all matrices and putting them on a table
eingenvalues1 = []
for i in lenghtdf1:
    primeiro = eingenvaluedf1[i]
    valor = primeiro[0].round()
    eingenvalues1.append(valor)

# %%
pidf1 = []
for matriz in eingenvectordf1:
    vetor = matriz[:,0]/(matriz[0,0]+matriz[1,0]+matriz[2,0]+matriz[3,0])
    pidf1.append(vetor)

# %%
lenghtdf1 = list(range(1,9222))
classificacaodf1=[]
for i in lenghtdf1:
    matrix = pidf1[i]
    GT = matrix[2]+matrix[3]
    AC = matrix[0]+matrix[1]
    if GT>AC:
        classificacaodf1.append('leading')
    else:
        classificacaodf1.append('no')

# %%
classificador = pd.DataFrame(classificacaodf1)

# %%
df2['is it leading'] = classificador

# %%
df2
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.358242  0.182401  0.203805  0.255553  0.280322  0.226452  0.144286
# 1     0.320226  0.201471  0.252032  0.226270  0.260640  0.228051  0.209217
# 2     0.390224  0.169756  0.146904  0.293116  0.350484  0.198594  0.199835
# 3     0.422516  0.146274  0.156172  0.275037  0.405465  0.165853  0.059420
# 4     0.344484  0.189148  0.202895  0.263473  0.274323  0.324033  0.178111
# ...        ...       ...       ...       ...       ...       ...       ...
# 9217  0.217677  0.277106  0.258102  0.247115  0.198807  0.240962  0.403286
